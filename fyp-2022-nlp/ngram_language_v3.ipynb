# %%
from nltk.lm.preprocessing import padded_everygram_pipeline
from sklearn.linear_model import SGDClassifier
from nltk.util import bigrams
from nltk.lm import Laplace
from nltk.lm import KneserNeyInterpolated
import nltk 
nltk.download('punkt')
from nltk.tokenize import word_tokenize

import re
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/alexandernielsen/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
FILE_PATH = 'data/hate/train_text.txt'

# %%
def tokenize_lines_list(file_path):
    line_list = []
    with open(file_path, 'r', encoding = 'utf-8') as f:
        lines = f.readlines()

    for line in lines:
        tokens = word_tokenize(line)
        line_list.append(tokens)
    
    return line_list

# %%
tokenized_lines = tokenize_lines_list(FILE_PATH)
training_size = (len(tokenized_lines) // 5) * 4 #80% of the original dataset

training_data = tokenized_lines[:training_size] #slice to training data
validation_data = tokenized_lines[- (len(tokenized_lines) - training_size):]
# for line in tokenized_lines[:training_size]:
#     training_data.extend(line)

# %%
all_tokens = training_data
all_test_tokens = validation_data

list_of_ones = set()
my_dict = {}
tokens = []

for i in all_tokens:
    for j in i:
        tokens.append(j)

for i in tokens:
    my_dict[i] = 0

for i in tokens:
    if i in my_dict:
        my_dict[i] += 1

for i in my_dict:
    if my_dict[i] == 1:
        list_of_ones.add(i)

for i in all_tokens:
    for j in i:
        if j in list_of_ones:
            j = '<UNK>'

# %%
print("list of ones: ",len(list_of_ones))
print("my dictionary: ",len(my_dict))
print("regular tokens: ",len(tokens))
print("all tokens: ", len(all_tokens))
print("all test tokens: ", len(all_test_tokens))
# Out:
# list of ones:  12548
# my dictionary:  20674
# regular tokens:  180683
# all tokens:  7200
# all test tokens:  1800

# %%
print(tokens[0])
print(all_tokens[0])
# Out:
# @
# ['@', 'user', 'nice', 'new', 'signage', '.', 'Are', 'you', 'not', 'concerned', 'by', 'Beatlemania', '-style', 'hysterical', 'crowds', 'crongregating', 'on', 'you…']

# %%
# training corpus 
all_strings = '\n'.join([' '.join(e) for e in all_tokens])
corpus = all_strings.lower().split('\n')
vocabulary = word_tokenize(all_strings)

# %%
corpus
# Out:
# ['@ user nice new signage . are you not concerned by beatlemania -style hysterical crowds crongregating on you…',
#  'a woman who you fucked multiple times saying yo dick small is a compliment you know u hit that spot 😎',
#  '@ user @ user real talk do you have eyes or were they gouged out by a rapefugee ?',
#  'your girlfriend lookin at me like a groupie in this bitch !',
#  'hysterical woman like @ user',
#  'me flirting- so tell me about your father ...',
#  "the philippine catholic bishops ' work for migrant workers should focus on families who are `` paying the great ...",
#  "i am not going after your ex bf you lieing sack of shit ! i 'm done with you dude that 's why i dumped your ass cause your a lieing 😂😡 bitch",
#  'when cuffin season is finally over',
#  'send home migrants not in need of protection , peter dutton tells un , hey dutton how about the ones that have stayed and not left the country when they should overstayers ? why dont you go and round all them up ?',
#  'cory booker and kamala harris competing for most hysterical woman at the kavanaugh hearings , coulter hilariously tweeted.and yes , liberals immediately got triggered on twitter , saying her joke was offensive . to them we say , suck it up , snowflakes .',
#  "only that in you which is me can hear what i 'm saying . ~baba ram dass",
#  "should have let the libyan manchester bomber rot in his own country . how many more mass murderers did the royal navy import to britain ? how many more terrorists do the ngo 's rescue from international waters ? # refugeesnotwelcome",
#  'more migrants take sea route to # spain than italy this year : un',
#  'essential reading for those in scribner , nebraska who are considering an anti-immigrant ballot measure .',
#  'this account was temporarily inactive due to an irrational woman reporting us to twitter . what a lack of judgement , shocking . # yesallmen',
#  'rt @ user @ user i am flattered tbh . i got an orgasm just by thinking of it you really are good at this .',
#  'making them look ~anatomically correct~ just makes them ... bland . not all women are tiny and fit , not all men are bulky .',
#  'listen ... i love lil b but i would not fuck with dej loaf at all . she prob got poison up in her nail polish like that bitch from holes',
#  '@ user @ user keep calling her a bitch and a whore dude real grown up .',
#  "glad your having another nice vacation . how 's the illegal border crossings , illegal oportunistic migrant entries , tax payer funded hotel rooms for same without a strategic plan going ? @ user @ user @ user @ user @ user @ user",
#  '@ user unchecked population & amp ; migration to cities is biggest evil for dirty india.disincentive large families , such as withdrawl of sops',
#  'illegal alien hit man , dragged him for blocks in deadly dui crash # buildthewall # noamnesty # nodaca # deportthemall # keepamericasafe',
#  'an honest article about illegal immigration by a lefty ? ? are pigs flying ? - a miracle ...',
#  '@ user @ user @ user @ user please spread the word - & gt ; & gt ; using frequent flyer miles to reunite immigrant families !',
#  "knuckle up cause i 'll fight for mines yo pussy petty , u wasting time .. u seasonal , part time u get fucked up fuckin w/ mine u lil bitch",
#  "yes , women who protest are 'irrational ' 'hysterical ' 'bitters spinsters ' - long history of using that shit to dismi…",
#  '@ user not all men are animals . you libs want muslims to come over still ? better pick a side .',
#  "federal judge to # trump : `` imminent danger '' of `` irreparable injury to # refugees , visa-holders '' , etc . @ user",
#  "this bitch whom i wo n't name on facebook is such a shameless woman ruining a relationship . # getalife # stopspreadinglies # hoe",
#  "@ user @ user omg he gave her his number and she did n't say no what a cunt the girl is the cunt for giving it to some random fucktard",
#  'why we need to protect refugees from the ‘ ˜big ideas ’ designed to save them @ user @ user @ user @ user @ user @ user @ user',
#  'kevin rosero of the latino immigrant experience oral history project # njhric # newarkpubliclibrary needs help identifying newark latino immigrant residents to interview and capture their stories and experiences . more info :',
#  '@ user are you pussy grabbing tonight ? ?',
#  "some people really dont understand why i get so upset at injustices happening in this country . trust me , it 's not that i like getting my panties in a wad over dumb things . it 's the fact that people like me ( minority , brown , immigrant , etc ) r suffering and it affects me directly",
#  "i 've been called a son of a whore and a cunt today already . it 's not even 1 yet",
#  'pope francis : immigrants provide ‘ ˜enrichment ’ to society , not ‘ ˜threats ’',
#  'what were they planning to do with the immigrant children they kidnapped ? slavery , sex traffic , organ harvesting ?',
#  'masturbate intensive for that whore slut',
#  'the truth about # immigration',
#  '@ user @ user must make illegal # immigration and over stays a felon pass mandatory e-verify for # jobs and welfare # trump # maga # rednationrising',
#  '@ user immigration on mass in europe kills our culture our languages and over stretches our own resources such as hospitals , schools , now italy , greece , etc , your right send them back home but please do not separate families islamic countries',
#  'lebanese christian victim of a quarrel between syrian refugees carrying knives & amp ; cleavers in lebanon',
#  'corecivic found its best interest is to grow us detention capacity , for women and children , by over 450 % . expanding the number of mother-child beds from 3,500 up to 20,000 . this signals the largest increase in immigrant detention since ww2 # resisticenashville photo : julie henry',
#  'i wonder is this is where caitlyn gets his car services 🌚',
#  '@ user uhhhhhh , that ’ s stupid little bitch , ma ’ am 😉',
#  'bishop appeals to church groups to take action as migrants now account for 11 percent of reported cases',
#  'because some women are stupid',
#  '@ user bitch text me',
#  'because they had a cross on ! ! the lovely nhs can not get 100 indian doctors over from india because of immigration rules , good do we want to hire from a land of rapists and ignorant beliefs sadly we can not get enough training places here , why dont we use nurse practitioners #',
#  "@ user rt @ user do n't betray your # voters on # immigration . # americans , # wethepeople , & the # usa reject # daca , # amnesty , the # dreamact , & all # illegal immigration . do not break our constitutional laws . deport all illegals & # daca immigr",
#  "@ user elizabeth warren 's radical agenda to abolish ice and create open borders must be stopped . geoff diehl is the only candidate with a proven record of fighting illegal immigration . vote for @ user for senate in ma",
#  'what an absolute cock womble this cunt is . does she also alude to the fact she recieved free university education aswel .',
#  'no matter what color a girl is she still a ho 😂😂',
#  '@ user i am not forcing anyone . i am just putting out my view . people believe it or not is their prerogative.even if a single person agree with me , it is ok with me . thanks ,',
#  '# factcheck 👍 # boycottunitedarlines # aidingandabetting # felons # wethepeople are fed up # enoughisenough # ice # dhs # doj # wakeupamerica # stoptheinvasion',
#  "# nrc assam govt must initiate immediate action 2 cancel voting id cards & amp ; aadhaar cards of the identified illegal migrants let `` commited '' political dogs bark any length & amp ; as loud as they can nation must remain firm on its security concerns",
#  '@ user dan , way too tough to choose between all the lying , deceitful corrupt losers representing dems ( & some gop ) . the list is long & disgusting . embarrassing that we pay these lying losers large salaries to corrupt our democracy. # maga # kag # potus # tr',
#  'russia , turkey , jordan are in talks on return of syrian refugees ‘ “ lavrov',
#  "@ user @ user no ..... really ? a refugee ? they are here to enrich our cultures , right ? i bet ya he 's older than 17 too .... # sendthemback it 's not late to save europe",
#  'neverrrrrrrrrrr',
#  "thank you , @ user for taking a stand . it 's up to all of us to fight misinformation and anti-immigrant hate . # sourcesmatter",
#  'and now another flood of immigrants coming our way. # buildthatwall',
#  'nothing irks me more than when bitches end it with a good guy then complain about getting hurt by a douche bag . # wakeupyouwhore',
#  'realizing the rights of eritrean refugees in israel . a new article : https : //t.co/0sstuvgq6z',
#  'judge orders government to release immigrant kids from texas shelter | the texas tribune',
#  "@ user @ user @ user do n't dare to tell us about syrian refugees .",
#  '@ user @ user it should foment anger . only idiots open their borders to people who will never assimilate . majority of black africans coming into europe are not refugees and had the money to pay for trip over , which is expensive .',
#  'this is what trump supporters call humane smh',
#  'megynkelly is skank . whore paid $ $ for what ? only thing left to watch on . @ nbc anymore is snl . more truth to them t…',
#  "# occupyicephl was delighted to learn that charlie kirk , the anti-immigrant , anti-muslim , conspiracy theory-touting , founder & amp ; executive director of the white nationalist-allied turning point usa ( tpusa ) did n't have a very good morning either . # nationalistsnotwelcome",
#  'med not a house/eu not adult day care camp for migrants seeking handouts or to profit from crime.tunisia abusing # italy eu , which has leverage bt lacks courage to use it . # salvini must send messageðÿ ‘ ‰either stop boats & amp ; take back citizens or we bury you economically , esp . leaders',
#  '@ user good girl',
#  "you know your women are stupid just like you're_ bitch please did i fuck you_ what importance do you have in my life_ are you retarded_ 😏🌹",
#  "do n't you hate how girls just whore around because they never got daddy 's attention ? ? and so they have to interfere in relationships .. hoe",
#  '@ user greedy , you have to talk about this tomorrow including the hysterical responses .',
#  '@ user wow ! ! never seen a woman juggle a big cock like that',
#  'fuck you , you hoe i don ’ t want you back',
#  '@ user screw her and her beliefs ! ! send them packing ! ! this is a christian nation with christian laws . # buildthatwall # kag',
#  '@ user you are the sloppy queen of sucking cock',
#  'world relief is continuing to provide legal aid and advocating for immigrant families who have been separated at the u.s.-mexico border . you can make a difference and help reunite families by making a donation today . âž\x9d',
#  '@ user africa for africans , asia for asians , white countries for everyone is white genocide.some basic truths : access to white people is not a human righthttps : //t.co/c0ghvd6imbremigration 2018 : easy come , easy go ! !',
#  '@ user you dumb cunt you trick 12 and 30 year old virgins into giving you money you fucking bitch . kys honest…',
#  'from refugee to sole survivor - how one syrian has become shoemaker to the famous',
#  "@ user @ user @ user @ user earth to andrew , come in andrew : its about immigration.denying canadians their right to survive and defend their racial interests is 'racial hatred ' . in fact its white genocide . its a crime : access to white peopl",
#  "when you 're sneaking in after a long , hard night of cheating and do n't wan na wake your girl cause you 're a good guy",
#  '@ user sweetie , how the hell can you take “ oh my god that ’ s a dick ? ! ? ! ? ! ? ! ” style monologue',
#  'absolutely perfect keep the whole lot of illegal aliens out , now maybe libtarded snowflakes will be happy they are not being split up ? # maga # kag # nodaca # noamnesty # buildthatwall # buildthewallnow # buildthedamnwall # buildthewall',
#  'hundreds of syrian refugees return home from lebanon - abc news',
#  'video : immigrant activist who climbed statue of liberty has a new song : `` america , you motherfuckers , ...',
#  "turkish government must immediately take precautions to protect it 's borders and find solution for the trouble in syria or else turkey will be a refugee storage in the near future and this is a big threat for our survival # nomorerefugees",
#  "//'we will send back the illegal immigrants to bangladesh . tough days are ahead , we will not tolerate any illegal immigrants in bengal . 'with these statements , west bengal ...",
#  "rt @ user i bet a lot of people 's therapists are dying to meet me just to see if the stories are true .",
#  'holleringgggggg . stupid baby bitch .',
#  'a bitch in which i find attractive can take her sock off and my dick will suddenly become hard as shit ..',
#  "rt @ user 'you miss 100 % of the shots you do n't take . ' -- wayne gretzky",
#  "@ user actually that is any benefits which would make a immigrant a `` public charge '' law on the books for over 100 years not entitled to hold a green card or become a citizen but # dems wont enforce it ! that is why 73 % of mexican and central amer",
#  'how much is john mccains funeral costing tax payers ? not including his no vote to scrap obamacare . next time use our hard earned money for something useful like building the wall ! ! # buildthatwall # mccainfuneral # baloney',
#  "i 've never in my life met a woman who was smarter then me . maybe that has to do with their small retard brains ? # womenaredumb ..",
#  'syrian activist alleges un gave rakban camp refugee children expired sweets',
#  '@ user i bit my toungue when l heard syrian refugees complain about rothsey then again , maybe someone can swop them with a high rise',
#  "@ user list fails without '50 things to think about to stop you doing your beans ' by kunt and the gang",
#  "sweden dentist fined nearly $ 50,000 for revealing that many adult muslim migrants are posing as 'unaccompanied refugee children ' via @ user swedenstan update ...",
#  'the us bill is an illegal endeavour and can not impact the current situation . it is a part of the “ deal of the century ” which aims to revoke the palestinian refugees ’ right of return and works hand in hand with the israeli racist nation state law ,',
#  'ugh ! fake christians really out here trying to take away our rights ! ! if you care so much about life then fix the already broken foster care system and welcome refugees with open arms . follower of christ ? ? while not loving your neighbors ? yikes .',
#  '@ user lmao on my grandmother , you never knew me in 2012 so stop while you really ahead hoe',
#  "could you please explain why you praised the research of an anti-muslim and anti-immigrant foundation linked to orban 's far-right government ? or why you are hosting events at the hungarian embassy for this foundation ?",
#  'was a legal resident until she was convicted of shoplifting deported then came back illegally now she wants u , s taxpayers to pay her medical bills # sendherback let her family go with her ! # immigration',
#  'italy and france try to patch up migrant row , draw papal rebuke send them to the vatican ...',
#  "@ user @ user in an interview with @ user trump does n't need congress to build the wall.we are being invaded by a foreign country ; defending our borders is the # 1 job of the commander-in-chief , use dod funds . `` please @ user",
#  "if you hate fuckboys it 's only cause you let one break your stupid little heart ... dumb dumb",
#  "@ user then do n't be a whore and open your legs for everyone , and not fuck everyone you want , and magically , you 'll prevent getting an std .",
#  '@ the broke bitches who are partying in my ovaries . i hope you fucking die and rot in hell you stupid ugly ass bitch',
#  '@ user @ user we need to keep saying it until its built ! # buildthatwall',
#  'ice : 124 illegal immigrants released from jail later charged in 138 murder cases # buildthewall # enforceuslaws # keepamericanssafethis is all the congress should be comtemplating ! # bansanctuarycities # noamnesty # nodacadeal # endchainmigration # deport',
#  '@ user facts ! like bitch stfu & sit in the corner hoe . catch a fit in the corner , facing the wall',
#  '# information_warfare',
#  'here comes the results of socialism . to all liberals who want communism ; here comes your new roomies . # buildthatwall',
#  'iraqi immigrant accused of critically wounding colorado cop evaded deportation despite criminal record',
#  'and why should he now buckle to their demands that he swear undying trust for these a * * * * * * * ? ? ? ? ? they are the enemy of this nation ! # treason',
#  "trump administration may be creating 'permanently orphaned ' immigrant kids , judge says – texas monthly",
#  '@ user families should not bring their kids into a country illegally , would you ? we can ’ t afford them # sendthemhome',
#  'effects of third world immigration into canada via @ user',
#  'things got heated : breaking : woman sets pedophile muslim man on fire after catching him rape 7 -yr -old daughter',
#  '# factcheck true # wakeupamerica # leftistsedition # democratshateamerica # openyoureyes # freeyourmind # buildthewall # stoptheinvasion',
#  'youth # care worker accused of sexually abusing # immigrant boys - # prescientinfo',
#  'this year a young immigrant from mali saved the life of a child in france . the president of france personally awarded him a national hero medal for bravery after inviting him to the elysée palace , offered him french citizenship and a job . this year , the…https : //t.co/hkdegti5ya',
#  "'come up here and say somethin now you broke , beggin , fingers in the booty ass bitch '",
#  'goals af',
#  "hmm ... someone named `` garcia '' wants to eliminate the us/mexico border . imagine my surprise.what 's it called when a foreign agent enters your country & amp ; sabotages your # bordersecurity for the benefit of their own country ? # stoptheinvasion # securetheborder # buildthewall # noillegals",
#  '@ user coming from a hysterical woman .',
#  '@ user hahahahahahahaha no wonder you work for the sun you thick kunt .',
#  "@ user you guys nailed it . i 've had 3 seperate fits of hysterical laughter and i did n't even make it to the school yet .",
#  'american # familiesbelongtogether but the # democrat socialist party keeps allowing illegals to kill them # familiesbelongtogethermarch # americansfirst not illegals breaking # inmigration laws',
#  '@ user this your whore you going to marry and lie to me about will never marry women who show body to public',
#  'russian immigrant seeks democratic nomination for alaska ’ s u.s. house seat',
#  'dawgg im fr boutta roast this bitch lmfoaoo dont ever post ian again u stupid ass slut',
#  'fox news host : lock clinton up get this cunt pirro off the air . she is a woman hating woman .',
#  '@ user sorry sweetie , but women are the causes of all problems',
#  'thousands march in # munich to show support for migrants',
#  'how to pronounce whore eyed cunt ↺rt❤ #',
#  '@ user bitches love electric toothbrushes in their twats ...',
#  'can you bitches stop pulling ya pants up above your belly button , you look like my fuckin grandfather',
#  'last week , her justice staff members spoke about immigrant detention , focusing on the inhumane treatment and poor conditions they observed volunteering at south texas family residential center in dilley , tx and how chaotic policy changes continue to adversely affect detainees .',
#  '@ user : vogue hijabi cover star on growing up in a # refugee camp via @ user # withrefugees # worldrefugeeday @ user @ user @ user @ user',
#  '* croatia ðÿ‡\xadðÿ‡· : last wednesday , illegal migrants from iran were detained in a neighborhood near zapreå¡iä‡ . # v4 # visegrad',
#  "paris dont like tentrefugees . now they bring them to the parque `` bois de bologne '' . close of this place life the most rich people of france in the avenue foch . the rich have made big walls around their property .",
#  'alabama : illegals force 13-year-old girl to watch murder of her grandmother , then behead girl # illegalaliens # alabama # animals # kag # rolltide # walkaway # lockthemallup # sendthemback # buildthewall # maga # trump # trump2020 # qresearch # patriotsfight # redpill',
#  "like if you didnt want to have a party , do n't fucking broadcast it # thatstheshitidontlike # womensuck",
#  '@ user cameron you could not stop migration in ur one of many broken promises y do we need to stay in europe to rub it in',
#  '@ user i know you do , slut',
#  "when you thought you 'd try a little s & ; m and now your ass hurts so bad you can hardly sit",
#  '\u2066 @ repmcclintock\u2069 has voted to destroy the # aca more times than i can count . don ’ t give him another opportunity . choose to support healthcare , science , immigrant rights , civil rights & amp ; social justice . choose \u2066 @ morse4america\u2069 # teammorse',
#  'cocks of the beasts we keep . the life of a slut or breeding whore is quite exciting . ”',
#  'immigrant health workers in the uk',
#  "that 's the original it came from . but i appreciate the fact that you think i would follow or steal from u . sit down",
#  'illegal immigration drives up real estate prices , widens wealth-gaps , reduces high-tech investment , increases state and local tax burdens , hurts kids ’ schools and college education , pushes americans away from high-tech jobs',
#  '@ user some women are aggressive , promiscuous whores , but all women must try harder not to make men feel uncomf…',
#  'totally out of control . these people @ user @ user @ user @ user need to be reigned in . hotel rooms for opportunist migrants , millions being spent trying to stuff the genie back in the bottle , no end or strategy in sight .',
#  "@ user wake up & prepare to stop the evil dead in it 's tracks ! # sendthemback # deporttheundesirables # kickoutthelyers # savetheworldundertheonetruegod",
#  'please rape my slut cunt and fill it up to the brim with thick , hot cum',
#  'as long as the position is on all fours who cares',
#  '@ user well stfu then bitch you coming to some yeen got no business being in . you need to mind the business that pays you hoe',
#  'when the pizza man is more than a minute late',
#  "libya tells italy : `` we do n't care how much you pay us , we do n't want to take back the migrant wannabes that you reject because “ they include terrorists , criminals , and human traffickers '' via @ user",
#  'you ever be talkin to someone that you really wan na fuck , then they say one thing and all of the sudden you have no desire to fuck at all ?',
#  '500,000 angry democrat women swarm hollywood to protest rampant rape , misogyny and sexism oh , wait ............. ne…',
#  'number of illegal migrants in ukraine grows by 22 %',
#  '@ user i get suspended at least every other day . but you still see that skank whore chelsea handler still tweeting away .',
#  "rt @ user her : i do n't get what u want outta this relationship him : well , i was only looking for a bj but u kept coming back",
#  'imagine when all the eu migrants go home after # brexit . no more baguettes or pizza . people in the uk will be reduced to just eating traditional uk foods . like chicken balti .',
#  'an undercount would allow the federal government to direct resources away from california , which has the largest # immigrant population in the country . # census takers could miss counting millions of # californians , researchers say',
#  "nikki haley : un can ’ t 'dictate ' us immigration policy",
#  'i can not stand girls that always have to have a boyfriend . # attentionwhores # womensuck',
#  '@ user why you getting so hysterical .',
#  'this women can do only one think , back into her rat🐀 hole never to come out again🐀if she show up on surface am call…',
#  '# actnow ! # usa # eb5 # eb5visa # immigrant # foreign # investor # visa program laws are changing ! $ 500k # investment . payment plans available . use # bitcoin # ether # cryptocurrency . become a us citizen ! visit us at contact us today at gbibuildingco @ outlook.com . rt',
#  'the latest : spanish pm lets migrant boat dock at valencia you idiots are killing spain with islamists ...',
#  'afghan and pakistani migrants were shot at as they tried to invade hungary - free speech time - @ user',
#  '@ user shut the fuck up hes not gon na dick you was gon na send u this dope steroline edit but u can go cry to olly',
#  "you low life scum , pathetic , deprave , pile of shit , maggots . like i said that brainless skank bitch should 've died…",
#  '@ user @ user bitch we r now txf sluts',
#  '@ user at the very least ryan and mcconnell need to force the dems to vote against the wall .',
#  'russia liquidates its us treasury holdings | zero hedge no surprise here ...',
#  '# factcheck wow # factsmatter # votedemsout # redwaverising2018 # stoptheinvasion # buildthewall # deportthemall # endsanctuarycities # takeamericaback # walkawaymovementgrowing # maga',
#  '@ user @ user @ user this can not be allowed to happen -- -- child kidnapper and molester miller needs to be gone !',
#  '@ user ids the man who smirks at his own policies and implications on his own people y wont he admit its migration that fuels this',
#  'un seeks new funding pledges for palestinian refugees ...',
#  '@ user total lie . cong is the main culprit for influx of illegal migrants both bangladeshis & amp ; rhongyias . if they deported few , millions came during their tenures & amp ; they encouraged muslim illegal migrants & amp ; shooed away hindu migrants',
#  'sigh ...',
#  'immigration will not make america great again',
#  'obama , our smallest president . must take credit for all good ; disavows all that was bad during his 8 year assault on our great country. # maga # kag # potus # trump # news # votered # nodaca # walkaway # americafirst # usa # backtheblue # alllivesmatter # liberalismisamentaldisorder # nra',
#  '@ user this trashy whore gold digger at again trying be something that makes her think shes good ughhh not happening hoe bag pos',
#  'when his dick game is garbage but his mouth game is fire af',
#  '“ the verification will play a key role in establishing refugees ’ identities and their declared places of origin in myanmar . it will help to preserve their right to voluntarily return home , if and when they decide that the conditions are right to do so . ”',
#  "i recently read a book with a passage between a woman and a powerful man . i had to ask author if it was rape or nah . that 's how blurry it is",
#  '# rohingya refugees move to higher ground to avert loss of lives in the upcoming monsoon season # ucanews # voiceforthevoiceless # refugee # bangladesh @ user @ user @ user @ user @ user',
#  'tesla driving russian immigrant running as a democrat for us house seat in alaska',
#  'never try to holla at women who dissed you in his school i got called misogynistic egotistical whore monger damn bitch ok have a nice day 😂',
#  'hiv-positive shelter worker in mesa sexually abused 8 immigrant boys , authorities say',
#  '# teenwolf # menstruafacts question of the day : when does a # feminist forget feminism ? answer : when the restaurant check hits the table .',
#  "`` the church 's position on immigration will define its witness to a hurt and broken world . '' - welcoming the stranger . this updated book is written by world relief 's matthew soerens and jenny yang . find your copy today !",
#  "@ user @ user grant you the first point , but it was a joke more than an insult.about the second point though , calling an hysterical person hysterical does n't set anyone back . there are hysterical women ( and men ) , bitches and douchebags , ass",
#  'no your not ! you are scroungers/soldiers coming to create a caliphate or create chaos . go home , look after your girlfriends/wives/kids . all fighting age . the last thing you are , are refugees ! bugger off ! bye , bey , cheers ....',
#  '# act4_southernsyria apparently secret meeting this week bet # angelamerkel @ user & amp ; russia fm lavrov & amp ; headrussian army- # europe will come in & amp ; help rebuild # syria , which russia wants -sothat what europe wants most can materialize ‘ “ returnof # refugees -german journo # datelinelondon',
#  'make canada like hungary again : prime minster viktor orbã¡n has vowed to not allow his christian country to be changed by incompatible jihadi invaders . orbã¡n , has warned : “ europe is under invasion , countries that don ’ t stop immigration will be lost ”',
#  "i am an immigrant . i live with my child . i am a 29 year old female . i earned $ 13,000 last year . i work 40 hours per week . i have a bachelor 's degree in accounting . i live in mi cc'rep . john moolenaar . # immigrantsareus",
#  'africans having their say about blacks in europe , and europeans in africa , at the # landexpropriationhearings , currently underway in # southafrica . # sendthemback',
#  'dems suggest kavanaugh should not be considered for scotus b/c # trump is under investigation ! never mind that said investigation is a trumped-up phony witch-hunt begun by dems in the 1st place # potus # maga # draintheswamp # votered # news # nodaca # kag # getoutthevote # buildthewall',
#  "he is in and out of jail . he 's a bum , he a pussy bitch ! he just ai n't shit ! i pray his next child he do wayyyyy better with fr .",
#  'u dont so why tweet it 😂😂 the only bitch u talk to is helllo me tf whore 🙄😂',
#  'the relocationprogramm of the eu doesnt work . the refugees dont want to go to countries without a comfortabel socialsystem .',
#  'illegal immigrant who killed kate steinle likely will be sentenced to time served # preventabledeath # buildthewall # stoptheinvasion # therismoreofthemoutthere',
#  'i ’ ve never understood why people stand and wait on they food at tolly ho ... you a good one',
#  'friend- how are you so carefree living a life of drinking , drugs and unprotected sex with complete strangers ? me-',
#  'most people and including me have no problem with immigration it the illegal immigrant that we think should be stopped and deported . there is a different between a legal and illegal immigrants .',
#  'virginia governor calls for probe into abuse allegations at facility that holds immigrant teens',
#  "when you and your girlfriend are so close that you 're best friends .. so much so that you just wan na tell her about the other girls ur fuckin",
#  "rt @ user it 's not her fault that your dick is extra special . it makes people daydream ya know ? xp",
#  'you stupid fucking whore mom',
#  'allies 10 year old brother is calling me a cunt and a bitch bc i asked him a question💀',
#  '@ user fucking cunt bitch has learned nothing from the election',
#  'illegal alien awaiting deportation for child rape , now caught producing child porn',
#  'the # commonweath of va welcomes all immigrants to its benefit and theirs @ user',
#  "denmark has cut welfare benefits for migrants - `` we 'll move to finland '' they threaten `` finland will treat us better '' - free speech time - @ user",
#  '@ user o right settle down 75 m turks could invade europe no more kebabs , cameron ur immigration policy as a nappy for constipated people',
#  '@ user no bitch you a hoe',
#  "shoutout to everyone accidentally blowing fingers off on video today so we can all have a good laugh tomorrow ... y'all patriotic af",
#  "women in their 30 's on vacation will literally fuck anything",
#  '@ user @ user # atlantahitrockbottoms this fool is promoting lawlessness from illegals and wants to turn atl into a 3rd world city like chicago and la . we are better than this brainless idiot ! # impeachbottoms # buildthatwall',
#  'her- can i stay the night ? me-',
#  "watch : merkel 's germany is starting to look like syria - immigrants set cars on fire `` just for fun '' - free speech time - @ user",
#  "i 'd say electrify the water but that would kill wildlife . # sendthemback",
#  '@ user the politics of hard done asylum seekers and designer immigration policies to help them into housing and nhs and other resources that can not be accessed by ordinary uk public all you do go on hunger strike or buy a budgie get some publicity whi',
#  'disgusting , and bitch you are no rock star ! ! you are a no class skank🤡😱🐍🙈🙉🙊👁',
#  'to use rape as a weapon towards women are far worse than using a bullet . only other men can help the women in burma . stand up for the women',
#  "trump 's border wall , immigration plans re-emerge at top of national debate # stoptheinvasion",
#  '@ user # nodaca # tuesdaythoughtsobama used dreamer illegal aliensto defraud the american dream # nodacadeal # americafirst clint eastwood was mocked forhis 2012 rnc speech , yet the new # obamapainting confirms obamais nothing but an empty chair.clint',
#  '@ user protect undocumented immigrants ? ? ?',
#  'president trump weekly address ‘ “ immigration reformâ needed ‘ ¦',
#  'how retarded must you be to have a skank shave your legs 🤦🏻\u200d♀️ # jeremykyle',
#  'pope to explore links between poverty and migration',
#  'the united states is a country founded by immigrants and dependent for its success on # immigration .',
#  '@ user not all men youre right doyoung wouldnt treat me like this ! ! ! !',
#  "well , i guess booker won the `` most hysterical woman '' award today ! ! ! ! !",
#  "left-wing spanish government deny 'mass ' migration : 'europe needs new blood '",
#  "@ user hillary clinton does give a shit about women that 's why she lied again she is now keeping all the harvey weinstein money greedy bitch",
#  '@ user @ user @ user immigration in a picturehttps : //t.co/bnrq7n7oj3',
#  'working on # memories # immigrant # lives # newyork # theworld @ new york , new york',
#  'rt @ user after three years of separation , a young syrian refugee hugs his mother in germany . the picture says it all . # familyreunification',
#  '@ user @ user @ user that ’ s right you the man # favoritepresident # buildthewall # stoptheinvasion # americansfirst one flag one country ðÿ‡ºðÿ‡¸',
#  '@ user # buildthatwall end # chainmigration replace # immigrationlottery',
#  "@ user whore ? really ? why do n't you have some respect for women you asshole !",
#  "'lawless area ' : german police conducts raid at refugee center after mob ... via @ user",
#  "marianna 's * status and documentation as the wife of a refugee was what she thought she needed ... however , only ...",
#  'preying on women is a bitch tendency ‼️🗣',
#  'ha ha bjp knows that hindus r so stupid that they r ready to starve with no jobs but first like to see ram mandir then taj mahal .',
#  '@ user melissa , you ’ re hysterical . 😂 i am giving you a happy dance for today🙌🏻',
#  "before @ user and @ user @ user was a young girl whose immigrant parents were deported . do n't miss her stunning memoir my family divded .",
#  '@ user if immigration will not stopped in europe , the refugees will destroy the welfare . this means streetfights and dead on european streets .',
#  'new blog post âž\x9d at world relief , we ’ ve welcomed and provided support to almost 300,000 refugees since 1979 . we love these strangers as neighbors because jesus calls us to . but we also do it because we know that ’ s what we ’ d all want for our own families .',
#  'because it ’ s easy to call women those things when the one hurting you repeatedly acts like he wasn ’ t being the slut and whore himself .',
#  'when you go to take a sip and and spill it on your face ... like wtf hand , why you let me down like that , bruh',
#  '@ user @ user skank , hoe , all these words you use to describe female artists.gosh , get a grip . do u…',
#  'the german government pays for 3 week vacation for refugees to go home the german government is actually giving refugees three weeks paid vacations including airfare back to the very countries that claim they are fleeing because it is unsafe . just',
#  '“ many of these parents were removed from the country without their child , all of this is the result of the government ’ s separation and then inability and failure to track and reunite , ” [ judge ] sabraw said .',
#  '@ user @ user @ user your a bitch who needed to shut his hole',
#  'have you heard ‘ wavy bassline mix ( halloween special ) ’ by the skank bank on # soundcloud ? # np',
#  "@ user @ user @ user what the hell is this ? is this part of the healthy conversation you were just preaching to us about ? she 's our first lady , like it or not . she 's also an immigrant , a mother and daughter , and fuck you for allowing this . ht",
#  "of i wan na scream ppl that stupid ! cube is the shitty company ? cube is cancelled ? ? no . edawn and hyuna went against rules.ofc cube pissed bc they did n't even listen to them ? ? what are you thinking ? sm jyp yg .. all of them will do same . just shut the fuck up anymore .",
#  'fucking take that stupid bitch filthy whore nobody will love you fuck you idgaf if ur pregnant ill kill u go ahead call the cops nobody wi',
#  'the dr.ron paul ! # makelibertywin # yalcon2018 # presidentpaul # endthefed # sendthemhome # liberty @ reston , virginia',
#  'wow , trump just did it : tweets video exposing dem/obama/hillary immigration hypocrisy',
#  "@ user war torn ? most so called refugees come from safe countries ! moron ! # fuckeu # leaveeu # sendthemback it 's the only option to save europe",
#  "@ user @ user these weak little men can not abide women who ... are alive ? this is today 's @ user too emotional to think . hysterical !",
#  "dutch prisons are so empty they 're being turned into homes for refugees via @ user",
#  'it must suck to not be me',
#  'it appears the left is out of control in germany as well , son murder and he is the bad guy , they are crazy for sure @ user @ user # buildthewall # lockthemup # enddaca # boycottnfl # boycottnike enough already',
#  'bitch mad cuz i nutted quick ... first of all yo pussy just good so be happy',
#  'how about a gofundme for a few hundred million dollars , to build a wall along the border side of this farm ? # buildthewall # buildthatwall # buildthedamnwall',
#  '@ user @ user lower taxes , raise the tfsa , stop immigration , end white genocide as government policysome basic truths : access to white people is not a human righthttps : //t.co/dimpwggsvz',
#  '@ user come on woman do your job right # womensuck',
#  '2017ðÿ ‘ ‰should eu take migrants from # italy when they already sent 100,000+to roam europe.all for @ user bt “ migrant sharing ” a nonsense & amp ; plays into hands of brussels , which seeks to commit eu to mass migration. # visegrad @ user',
#  'he is the new enemy ( h.kickl , minister of interior ) of the left comunistic-socialist-green groups which make business with refugees . he will do everything to bring refugees out of austria , this disturb the business .',
#  '# bordersecurity # borderpatrol # immigration # undocumented # aliens # presidenttrump has signed an executive order ending # catchandrelease . this is a huge , catch and release has been a ...',
#  'frustration and heartbreak as migrant parents look for kids',
#  '# immigrants # racist # trump',
#  'aw 😍😘 i owe you a mustache ride !',
#  'russian immigrant seeks democratic nod for alaska house seat ( from @ user by \u2066 @ beckybohrerap\u2069 \u2066 @ mthiessen\u2069',
#  '@ user beware usa + europe from illigal immigration !',
#  "when you 're tryna sneak out their crib quietly in the middle of the night",
#  "stop tweeting about your boyfriend . no one gives a shit . and you 're gon na break up in a month anyway # womensuck",
#  'young people taking care of business .',
#  '@ user the real @ user @ user bho & holder also killed @ user officer brian terry with his # fastandfurious debacle . many others died because of your negligence ? ? # buildthewall # deportthemall # nodaca # noamnesty # noworkforewi',
#  "@ user thank you for liking my 'not all men ' tweet btw",
#  '@ user another incident in germany will it be a drunk driver or another angry immigrant with issues innocent to proven guilty there is so much goodwill before it becomes salt in the wounds of a giving nation',
#  '@ user @ user @ user women are offended by his porn & rape essay stating “ a woman enjoys interc…',
#  'you got ta throw glitter after that . bitch pussy must be serious .',
#  '@ user @ user this old bitch needs to go out to pasture ! dig a hole too racist',
#  'large areas have been evacuated and people were moved to shelters to wait for the waters to subside .',
#  "i 'm at the plaza roberto maestas on beacon hill with @ user to stand with people of color and immigrant communities as a collective voice of engaged voters . watch live on facebook :",
#  'as the european union gives political cover to italy & amp ; other states blocking & amp ; threatening charities rescuing refugees & amp ; migrants escaping libya , death rate soars to staggering 1 in 7',
#  "@ user 'oh said a bitch who lost everything . you whore . '",
#  'was getting elbowed by a triple chinned cunt with nails like a woman ont train let a smelly fart out before moving…',
#  '# ice # illegalaliens # border # immigration # bringbackourborders # oakland mayor # libbyschaaf warned everyone in ...',
#  'my neighbour is such a cunt i hope someone murders that stupid bitch . preferably tortures her first as well',
#  'trump is correct he just said it the wrong way should the queen head of the british commonwealth just tell the shitty nations to buzz off certainly not but would the uk people vote to end the commonwealth l think yes less pressure on nhs housing etc brexit no to immigration',
#  'angel families hold rally to combat illegal immigration . # deportthemall # noamnesty # nodaca',
#  'why do women use them being on their period as a excuse to be a cunt ? you had it since you were 13 you can ’ t control yourself ?',
#  "while # forestfires are terrifying and tragic , should the fed . gov . grant # california assistance with which to fight them while it thumbs its nose at the rest of the country by protecting illegal immigrant criminals ? ( has n't cali been denying federal jurisdiction over its land ? )",
#  "do n't fucking toy with me # womensuck",
#  '@ user @ user @ user @ user @ user so you cant stand your own kind either you got ta breed with something else .',
#  'criminals not immigrants ! lets call them who they are if they did not come in our america legally ! they get no amnesty for breaking the american law . @ user @ user @ user @ user @ user @ user @ user @ user @ user',
#  '@ user lmaoo you pussy . what those emojis mean ? !',
#  '@ user @ user agree with your idea to use the army to build the wall ! do it ! # buildthatwall # buildthewall',
#  'over 62 million people voted for @ user b/c of policies clearly stated at dozens of rallies . # buildthatwall # taxcutreformbill # eliminateregulations # constitutionalistsonscotus # americafirsttradepolicy # endgovermentwaste # reformtheva # destroyisis keeping promices # maga',
#  'me after the walking dead season finale',
#  'int ’ l , 1st- and 2nd-gen immigrant students make up an average of 30 % of undergrads in u.s. -miriam feldblum , executive director , presidents ’ alliance on higher ed and immigration \u2066 @ aracelihlaroche\u2069 \u2066 @ megitasmith\u2069 \u2066 @ nmvalenzuela\u2069',
#  'when your friend moves away to be with someone ...',
#  'no one gives less fucks than a pitcher that intentionally hits a man holding a bat with a baseball',
#  'watch my snap story tonight it will be all over it 😇',
#  '@ user what some of these bitch part starlets promote to young is worse than rape it is rape of young minds . what goes around comes around !',
#  "angels do n't die . i think it 's better that two immigrant children in a concentration camp in southwest us die every time donald trump tweets , tweet tweet tweet tweet tweet like a bird .",
#  'iso several * new or used * items to foster greater self-sufficiency of a few recent refugee families : work boots , lunch boxes/bags , apt size microwaves , food storage containers , laptops ... and drumroll ... a large family ...',
#  "i love how i wasted 5 years on a stupid cunt . only to find true love with the beautiful woman i was with before that . life 's funny sometimes",
#  'we want the world to give us justice and make it possible for us to go back.the fact that we had to flee , we want justice for that . we ask for justice from the leaders of the entire world.https : //t.co/3jv0hnp8md',
#  'austrian , italian and german interior ministers discuss migration',
#  '@ user biggest menace affecting growth of india is its population.must take steps to curb population & amp ; illegal immigrants',
#  'at this time , w-organized crime/returning jihadists , it ’ s a matter of national security . # italy # salvini must ignore international social engineers/cultural marxists. # v4 italy kurz others must challenge empty threats from un-eu migration pimps . what can they really do about it ?',
#  'coding program in ny seeks to open tech career doors for immigrant girls',
#  '@ user i am serious and sure that i want to put my penis in the hole of your ass',
#  '@ user @ user @ user that bitch must have a strong back . she cant stop digging the hole shes in . jesus hilla m…',
#  'i ’ m watching kim ’ s convenience on netflix and honestly the immigrant/first gen experience in america is so universal . we really could all link up and be in this together except literally every immigrant culture ’ s # 1 rule is “ stick with your own ” lol',
#  '# landdegradation drives mass # migration , # climatechange . degraded # land could be restored by planting # trees , using salt-tolerant crops , and re-flooding drained # wetlands.ðÿœ²ðÿœ³ðÿœ´ðÿž‹ðÿœ „ # soil # landrestoration # landlivespeace # livelihoods',
#  'oh btw just to offend the femalesss cunt cunt cunt whore cunt whore slut bitchslut feministshit',
#  "@ user @ user @ user @ user @ user @ user you 're not welcome illegal immigrant . you belong to the low class monkeys who 's only good at dying everyday and begging the world to help them . such a poor godless nation . no wond",
#  '@ user @ user @ user @ user @ user @ user no one believes that myth ! legal workers line up for restaurant jobs after sheriff joe # immigration raids via @ user',
#  'me flirting- so how wealthy are your parents ?',
#  'a judge sentenced three muslim refugee boys in the sexual assault of a 5-year-old girl in idaho , but nobody knows ...',
#  "still baffles me that baylor 's football team can rape women w literally everyone knowing ( including the police ) and nothing is done abt it",
#  '@ user oh god , i can imagine that you ’ ll get even more men talking to you about some “ not all men ” “ not me ” bullshit 😤',
#  '@ user babe , i wan na thank you for having such insane anal scenes . your scene from slut auditions # 3 is my all-time fav !',
#  "@ user and that 's only the women that have posted it .. i wrote about the 'not all men ' culture as well -",
#  'sweden is almost like the perfect experiment on multiculturalism . wan na let in massive amounts of people from muslim majority and third world countries ? okay , get ready to become one yourself ! p.s . we told yah so ! # immigration # sweden # stopimmigration',
#  '@ user delhi have understood ur gameplan . u only focussing on ur votebank . no action against encroachments , filth in over crowded muslim areas . lot of muslim migration to delhi',
#  'there are good men out there women stop accepting ass holes that appear to be right.it is a excuse to turn lesbian cuz of a no good man .',
#  'for @ user ’ s clever i wrote about my shifting understanding of home , from those of the displaced communities in colombia , my grandmother ’ s handbuilt house , and my own as an immigrant :',
#  "could n't have said it better # yesallmen",
#  "@ user let 's get # prouddeplorable trending now ! please # retweet this # sundaymorning visit to help # buildthatwall",
#  '@ user sooo you trying to pimp em out . bet .',
#  '# buildthewallnow before the midterm elections @ user @ user @ user @ user # maga # makedclisten # noamnesty # nodacadeal # mandateeverify # endchainmigration',
#  "last i checked men have the penis and women do n't . i wo n't say it again but the dick is all that matters # mensrights !",
#  "# maledominance let 's get it trending !",
# ...
#  '@ user tells # trump not to give immigrants dna test to make sure their the kids parents just hand them over to child trafficers like obama # maga # rednationrising # fridaymotivation via @ user',
#  'some women will goto war for their nigga . i will leave your ass dead ass hanging i ’ ll never go towar with another bitch',
#  '@ user no , we should cover their transportation across the southern border & let them go on their way . # buildthewall # deportallaliens # noanchorbabies # nodaca # nodreamers # nocitizenship # nochainmigration # novisalottery # secureourborder',
#  '@ user @ user stupid as , it dosent make the mullas angry , the hole nation is angry',
#  'after libs help them avoid audit , california dmv finds 23,000 bad voter registrations # illegalaliens # buildthewall # nodaca # noamnasty # underminesourdemocracy # voteredtosaveamerica',
#  'at eu coreðÿ ‘ ‰54,000 “ relatives ” of migrants came to ðÿ‡©ðÿ‡ª last year for “ reunification ” . little sisters @ user wanted new limits at 1,000/month bt embassies already report 34,000 new requests . no end to delusions of merkel , csu. # visegrad # v4',
#  "the ' i ca n't get a date so ima just take one ' starter pack",
#  "nice to see the guardian acknowledging that mass immigration destroys culture and a people 's identity . i sure that was n't the intention of the article , but it is the truth .",
#  "mn : somali muslim immigrants explain why it 's acceptable to kill anyone who insults mohammed [ video ] via @ user we do n't worship mohammed & amp ; sharia ! do n't like it ? go home or we will deport you !",
#  "how many feminists does it take to change a lightbulb ? trick question , feminists ca n't change anything",
#  'our report on the lack of supervision , sexual activity and runaways at the shelters that house immigrant children in and around chicago was just published in spanish 👇',
#  "' i do n't want to be like the jealous girlfriend who wo n't let you have friends ' bitch you have to be my girlfriend first",
#  "only men have a dick they can insert without consent , and women doing other shit . not that women ca n't rape & amp ; sexually harass either .",
#  "let 's build that wall. # buildthatwall",
#  'in rome a house was cleared by police from refugees . look how nice the riots are at this mission .',
#  "remember when canadian pm justin trudeau said this ? well the tide is turning in canada as citizens tell him enough is enough ... we ca n't 'welcome ' this many # refugees .",
#  "you know you 're doing something right when you got haters ✌🏼",
#  '@ user massive explosion in muslim population , illegal migrants r root cause of pollution.focus on aligning them as good citizens',
#  "palestinians slam reported us plan to weaken un 'refugee ' agency # unitedstates ...",
#  '# worldrefugeeday is tomorrow ! you can help refugee rebuild their lives in the u.s. by joining our world refugee day campaign . get started âž\x9d',
#  'i really do cuss a lot though . cunt comes out of my mouth all day . men women and children . no ones safe .',
#  'asos and katharine hamnett team up on underwear line to support refugees',
#  'president trump participates in roundtable discussion on immigration ‘ “ 2:00pmâ livestream ‘ ¦',
#  '@ user we are gon na be friends # yesallmen',
#  "@ user @ user @ user here 's my point you dog of assad son of whore father of slut",
#  "every convo ever w/ an # mra : 'men are pigs . ' 'wtf men r not pigs u fugly femenazi cunt ima cut ur head off n fuck ur neck hole 4 sayin that '",
#  'refugees not welcome .',
#  '@ user i was in toronto last year . it no longer looked like canada . very sad situation . the canadians were good people.https : //t.co/7bhgps1ch0stop immigration . start deportations . we have the right to our homelands .',
#  "when you 're hungover af and you realize tomorrow is monday",
#  'me- dear ig , i follow all of your guidelines , please reactivate my account ig-',
#  'nelly should beware of other woman now trying to accuse him for rape .. ladies after this lady because if one does it others will try it too',
#  'the world divided over trumped up charges and more refugees drowning l blame the refugees who burnt and murdered christians their religion',
#  'these savages invade our country , disrupt cities , turn many into shitholes like where they came from and we the people are paying for this shit . how about taking or our own citizens , veterans and other americans in need ? to hell with these ungrateful idiots ; # sendthemback',
#  'i got offered once by a neighbor to go to a church down the street & amp ; thought about it but then found out a week later the priest was sexually assaulting immigrant women & amp ; threatening to call ice on them if they told . that was my sign to stay w my little shrine in my room 👋🏼',
#  'why is thos racist , homophobic whore @ user getting so much success all of the sudden ? like go away ugly cunt .',
#  'the most filled with misogyny ( calling women hysterical for the # metoo movement ) and victim blaming s * it . why does…',
#  "@ user i ca n't believe just what a poor state those roads in the pictures are in and why council has allowed so much development on those roads , oh thats right , its because of turnbulls insane immigration policy .",
#  '[ feature ] congolese refugees ask korean firm not to supply voting machines to their country',
#  "if rape is real why are n't more people reporting it ? just another feminist lie . ;",
#  '@ user go rape your whore of a mother',
#  'true af 😂👌🏼',
#  "skinny is not always healthy , tell that to hollywood.they would n't house the immigrants or refugees from obama 's wars n dare to say they hate trump bc globalist democracy.have they looked at paris france lately.poor people 's campaign should get more funding from dem or rep",
#  'the philippines is sending a catholic priest to kuwait next month to assist filipino migrant workers who escaped from abusive employers .',
#  "@ user @ user actually i do think women should be reclaiming 'cunt ' . it 's past time .",
#  "@ user meanwhile the same women need only to be 1 . not fat 2 . not a cunt and ca n't even pull that off",
#  "the head of the philippine catholic bishops ' commission for migrants has welcomed a kuwaiti court 's decision to sentence the employers of a murdered filipino maid to death .",
#  "if they do n't trust you enough to let you cheat in peace is the relationship really real ?",
#  "i 've reached a point in my life where i 've realized theres no such thing as a girl that wo n't hurt you . eventually they all will # womensuck",
#  'update—draconian measures are being taken to force burundian refugees in mtendeli camp in tanzania to return to # burundi despite their fear . here is an order by tanzanian authorities closing refugees ’ small businesses in the camp effective immediately .',
#  'women are stupid . they get cheated on and approach and fight the side chic . bitch who cheated on you ? who ? stupidity is unbelievable .',
#  '@ user i am not sure how much you have seen about this , but this is a pretty strange take on it . to say rape is the main plot point is dismissive',
#  'texts after calling me a slut and telling me i was a bitch and that no one liked me . when i went to the dean with my mom and showed him the',
#  'read me and @ user on the intra-palestinian feud that threatens long-term relief in gaza',
#  'i am not a morning person & i keep to myself because of it , you wan na be a smart ass & gim me attitude ? ? imma be a kunt to you',
#  "@ user do n't worry about it and go make me a sandwich woman . # womensuck",
#  "# tech # news facebook 's new political advertising policy denounced by immigrant , civil rights groups facebook 's new political advertising policy denounced by immigrant , civil rights groups a wide range of advocates for immigrants…",
#  'when you wan na eat your own ass',
#  'facts vs fiction about # refugees',
#  'blocking people is my cardio',
#  'i have condoms everywhere cause i bought a value pack once and never used one of them',
#  'how a $ 20 tip cost an immigrant her airport job . i was so happy to see this woman , who had a gofundme goal of $ 5,000 , reach over $ 42,000',
#  'illegal alien who had already been deported in the past returns to florida & sexual assaults a young girl then nearly beats her to death # buildthatwall',
#  '@ user please think carefully it is not about benifits it is about to many migrants ur already punishing our poor god will interven',
#  "calling some one 'dwight you ignorant slut ' is the only thing that would make this day better",
#  '@ user god i hate that dumb cunt with her shitty music and feminism™ , meanwhile her country is the rape capital of europe',
#  'am i piece of shit ? yes . do i at least feel bad about it ? absolutely not',
#  '@ user do it @ user # buildthatwall',
#  '@ user @ user germans are ok , like the rest of western europe , the immigration problem came from the east ( romania ) the are partly responsible for the no vote , also the eu being unelected can hardly claim to represent any european nation ..',
#  "@ user and i 'd rather shove the fat side of a wine bottle up your ass ... we all have our preferences 🌚",
#  '# nonsense we do not want this in us . # muslimban no people from these countries should be allowed without proper vetting . it is really scary imagine # sharialaw # enddiversity # endchainmigration',
#  'why do girls follow me ? all i do is make fun of them for how dumb they are # womensuck',
#  "if i ask you how many men you slept with and you actually know , you 're not the girl for me",
#  "# impeachtrump # republican # democrat just consider how different life would be today if hillary had picked bernie as her vp candidate , they would have beaten the orange king by 30 points , saving ss , the budget , immigrant children , and journalist 's lives .",
#  'wake up at 6 in the morning to hear @ user commentating on the game . guy speaks out of his butt hole , don ’ t know how you got this job 😒😒😒',
#  '@ user what if she enjoys it ? i think the days where women are forced to stay in the kitchen , not work , etc are over .',
#  'i grew up in an immigrant household . we were taught to embrace our heritage and celebrate our differences . here ’ s dad and i on my last trip home to jamaica . happy 56th jamaican independence day ! 🇯🇲 🎉🇯🇲 🎉🇯🇲🎉',
#  '@ user well i mean by all means do you but not all men are like that ! ! ! !',
#  '@ user girl people really do that , like damn bitch you so selfish you don ’ t wan na rt me and get me clout',
#  "`` often employers consider employees slaves as they think they have bought them [ because ] they pay them . '' # ucanews # thereforthevoiceless # women # migrants # abuse # bangladesh @ user @ user @ user @ user @ user @ user @ user",
#  'immigrant children being reunited with families in us',
#  'two immigrant fathers reunited with their young sons in new york',
#  '# stopchildabuse the next social movement will be about stopping women who abuse children . it is a real problem .',
#  'making fun of the gop for being hypocrites on all lives matter but not immigrant lives . than turning around and being a hypocrite on racist and offensive tweets & gt ; & gt ; & gt ; & gt ; & gt ; & gt ; & gt ; & gt ; & gt ; & gt ; & gt ; & gt ; & gt ; & gt ; & gt ; & gt ; & gt ;',
#  "bbc withdraws 'biased ' educational film about immigration via @ user",
#  '@ user and you are a hysterical cunt .',
#  "dreamer ' sodomized multiple boys , between the ages 7 and 9 via @ user # deathpenalty is too good for this dispicable creature. # buildthewall # enddaca what about the dreams this pos stole from these children ? i hope you burn in pits of hell !",
#  'doctors saw immigrant kids separated from their parents . now they ’ re trying to stop it . : separating immigrant kids from parents “ really is nothing less than government-sanctioned child abuse , ” the president of the american academy of pediatrics says . …',
#  'pro tip- always call skinny girls fat , they live that shit 🌚',
#  'it ’ s too much loose pussy in the world to be raping bitches . literally some of these skanks , goin on sight 💀💯',
#  'the media and the d party tried to destroy america with obama . they r hysterical cuz they afraid you will find out just how terrible they r',
#  'watch : muslim refugee calls on the un to take action against britain because the food is disgusting - free speech time - @ user',
#  "@ user @ user @ user oh sure thing ralph . can you tell us exactly how many of the `` refugees '' ( code for country shoppers ) have been deported ? @ user",
#  'yes exactly . works both ways . the amount of times i ’ ve been groped by some hysterical straight girl on a night out…',
#  'philippine catholic bishops want a total ban on the deployment of filipino workers to countries that do not have laws to protect migrants .',
#  'when you see your first pair of titties',
#  'nine people killed in booby-trapped house in mosul , once back from refugee camp',
#  'in germany gayrefugees get a special invitation for housing together .',
#  'me when i go anywhere , ever',
#  'poland ’ s interior minister defends anti-migration stance during visegrad meeting',
#  "do n't mind me ... i 'm just waiting for @ user to start ranting 🌚",
#  'my brother is such a dick to his girlfriend who is so damn nice and it literally pisses me off .',
#  '@ user # nodaca # noamnesty # noanchorbabies 2 illegals do not make a legal # buildthewall',
#  "i 'm actually really happy your ass got pregnant and that you 're having a shotgun wedding . karma is a bitch you cheating skank",
#  '@ user been digging the podcast . always liked you as an actor . keep doing your thing ! ! viva dick ritchie !',
#  'trump officials asked # jordan to end refugee status for twoâ million palestinians # jaredkushner ...',
#  "pro tip- stop waiting for me to care , it 's not gon na to happen",
#  "do n't miss # deathofanation while it 's on the big screens ... a courageous , eye-opening exposé of the truth about leftwing fascism , and tactics of the liberals - it took a legal grateful , intelligent immigrant to recognize and uncover the truth thanks @ user ! !",
#  'the wall should have names of americans who died in the hands of illegal immigration . as a reminder for why we are building it in the first place .',
#  'this bitch cunt whore slut every type of name deserves to fucking die u wildin for this',
#  'yall stay making post about the lgbt community . you quoted my tweet and started bitching like the insecure little brat you are shut the fuck up and go cry to your mommy . i dont give a fuck about what you have to say .',
#  '@ user first of all bitch fuck u , second of all we both hoes 😴',
#  'quite a lot of tension already exist in moria due to the approaching trial of the # moria35 and the death of an afghani refugee yesterday - due to health care limitations . more than 200 refugees protested in memory of the man who died and contested the living conditions in moria .',
#  'me flirting- tell me about your father ... start at the part when he left ...',
#  'sometimes i just wan na crash into psychic reading places and ask them if they saw that coming ...',
#  "i love how women can just talk all day about a nigga not being shit , but soon as a nigga say sum boutta bitch . y'all wan na attack the nigga",
#  'important : appeal from gm police for information re attempted rape of young woman at green lane patricroft at 11.30…',
#  'remember , this the same bitch that was on fox news saying rape culture was an attack on young men . its her pussy be…',
#  'greece begins mass deportation of muslim immigrants - turns their boats back to turkey - free speech time - @ user',
#  "@ user 3rd , you are a fuckin bird you dumb bitch so what anytime you got drunk and had sex it was rape ? ! i 'm sick of you feminazis",
#  'listen here dumb fucker you dont call rania “ whore ” and youre the only crazy bitch here😘 deactivate pls bc nobody c…',
#  'of course * control * increase the production of hateful invaders while exterminating the native species= # abortiongenocide # wakeup # stoptheinvasion',
#  ...]

# %%
vocabulary
# Out:
# ['@',
#  'user',
#  'nice',
#  'new',
#  'signage',
#  '.',
#  'Are',
#  'you',
#  'not',
#  'concerned',
#  'by',
#  'Beatlemania',
#  '-style',
#  'hysterical',
#  'crowds',
#  'crongregating',
#  'on',
#  'you…',
#  'A',
#  'woman',
#  'who',
#  'you',
#  'fucked',
#  'multiple',
#  'times',
#  'saying',
#  'yo',
#  'dick',
#  'small',
#  'is',
#  'a',
#  'compliment',
#  'you',
#  'know',
#  'u',
#  'hit',
#  'that',
#  'spot',
#  '😎',
#  '@',
#  'user',
#  '@',
#  'user',
#  'real',
#  'talk',
#  'do',
#  'you',
#  'have',
#  'eyes',
#  'or',
#  'were',
#  'they',
#  'gouged',
#  'out',
#  'by',
#  'a',
#  'rapefugee',
#  '?',
#  'your',
#  'girlfriend',
#  'lookin',
#  'at',
#  'me',
#  'like',
#  'a',
#  'groupie',
#  'in',
#  'this',
#  'bitch',
#  '!',
#  'Hysterical',
#  'woman',
#  'like',
#  '@',
#  'user',
#  'Me',
#  'flirting-',
#  'So',
#  'tell',
#  'me',
#  'about',
#  'your',
#  'father',
#  '...',
#  'The',
#  'Philippine',
#  'Catholic',
#  'bishops',
#  "'",
#  'work',
#  'for',
#  'migrant',
#  'workers',
#  'should',
#  'focus',
#  'on',
#  'families',
#  'who',
#  'are',
#  '``',
#  'paying',
#  'the',
#  'great',
#  '...',
#  'I',
#  'AM',
#  'NOT',
#  'GOING',
#  'AFTER',
#  'YOUR',
#  'EX',
#  'BF',
#  'YOU',
#  'LIEING',
#  'SACK',
#  'OF',
#  'SHIT',
#  '!',
#  'I',
#  "'m",
#  'done',
#  'with',
#  'you',
#  'dude',
#  'that',
#  "'s",
#  'why',
#  'I',
#  'dumped',
#  'your',
#  'ass',
#  'cause',
#  'your',
#  'a',
#  'lieing',
#  '😂😡',
#  'bitch',
#  'When',
#  'cuffin',
#  'season',
#  'is',
#  'finally',
#  'over',
#  'Send',
#  'home',
#  'migrants',
#  'not',
#  'in',
#  'need',
#  'of',
#  'protection',
#  ',',
#  'Peter',
#  'Dutton',
#  'tells',
#  'UN',
#  ',',
#  'HEY',
#  'DUTTON',
#  'HOW',
#  'ABOUT',
#  'THE',
#  'ONES',
#  'THAT',
#  'HAVE',
#  'STAYED',
#  'AND',
#  'NOT',
#  'LEFT',
#  'THE',
#  'COUNTRY',
#  'WHEN',
#  'THEY',
#  'SHOULD',
#  'OVERSTAYERS',
#  '?',
#  'WHY',
#  'DONT',
#  'YOU',
#  'GO',
#  'AND',
#  'ROUND',
#  'ALL',
#  'THEM',
#  'UP',
#  '?',
#  'Cory',
#  'Booker',
#  'and',
#  'Kamala',
#  'Harris',
#  'competing',
#  'for',
#  'Most',
#  'Hysterical',
#  'Woman',
#  'at',
#  'the',
#  'Kavanaugh',
#  'hearings',
#  ',',
#  'Coulter',
#  'hilariously',
#  'tweeted.And',
#  'yes',
#  ',',
#  'liberals',
#  'immediately',
#  'got',
#  'triggered',
#  'on',
#  'Twitter',
#  ',',
#  'saying',
#  'her',
#  'joke',
#  'was',
#  'offensive',
#  '.',
#  'To',
#  'them',
#  'we',
#  'say',
#  ',',
#  'suck',
#  'it',
#  'up',
#  ',',
#  'snowflakes',
#  '.',
#  'Only',
#  'that',
#  'in',
#  'you',
#  'which',
#  'is',
#  'me',
#  'can',
#  'hear',
#  'what',
#  'I',
#  "'m",
#  'saying',
#  '.',
#  '~Baba',
#  'Ram',
#  'Dass',
#  'Should',
#  'have',
#  'let',
#  'the',
#  'Libyan',
#  'Manchester',
#  'bomber',
#  'rot',
#  'in',
#  'his',
#  'own',
#  'country',
#  '.',
#  'How',
#  'many',
#  'more',
#  'mass',
#  'murderers',
#  'did',
#  'the',
#  'Royal',
#  'Navy',
#  'import',
#  'to',
#  'Britain',
#  '?',
#  'How',
#  'many',
#  'more',
#  'terrorists',
#  'do',
#  'the',
#  'NGO',
#  "'s",
#  'rescue',
#  'from',
#  'international',
#  'waters',
#  '?',
#  '#',
#  'RefugeesNotWelcome',
#  'More',
#  'migrants',
#  'take',
#  'sea',
#  'route',
#  'to',
#  '#',
#  'Spain',
#  'than',
#  'Italy',
#  'this',
#  'year',
#  ':',
#  'UN',
#  'Essential',
#  'reading',
#  'for',
#  'those',
#  'in',
#  'Scribner',
#  ',',
#  'Nebraska',
#  'who',
#  'are',
#  'considering',
#  'an',
#  'anti-immigrant',
#  'ballot',
#  'measure',
#  '.',
#  'This',
#  'account',
#  'was',
#  'temporarily',
#  'inactive',
#  'due',
#  'to',
#  'an',
#  'irrational',
#  'woman',
#  'reporting',
#  'us',
#  'to',
#  'Twitter',
#  '.',
#  'What',
#  'a',
#  'lack',
#  'of',
#  'judgement',
#  ',',
#  'shocking',
#  '.',
#  '#',
#  'YesAllMen',
#  'RT',
#  '@',
#  'user',
#  '@',
#  'user',
#  'I',
#  'am',
#  'flattered',
#  'tbh',
#  '.',
#  'I',
#  'got',
#  'an',
#  'orgasm',
#  'just',
#  'by',
#  'thinking',
#  'of',
#  'it',
#  'you',
#  'really',
#  'are',
#  'good',
#  'at',
#  'this',
#  '.',
#  'Making',
#  'them',
#  'look',
#  '~anatomically',
#  'correct~',
#  'just',
#  'makes',
#  'them',
#  '...',
#  'Bland',
#  '.',
#  'Not',
#  'all',
#  'women',
#  'are',
#  'tiny',
#  'and',
#  'fit',
#  ',',
#  'not',
#  'all',
#  'men',
#  'are',
#  'bulky',
#  '.',
#  'listen',
#  '...',
#  'i',
#  'love',
#  'lil',
#  'b',
#  'but',
#  'i',
#  'would',
#  'not',
#  'fuck',
#  'with',
#  'dej',
#  'loaf',
#  'at',
#  'all',
#  '.',
#  'she',
#  'prob',
#  'got',
#  'poison',
#  'up',
#  'in',
#  'her',
#  'nail',
#  'polish',
#  'like',
#  'that',
#  'bitch',
#  'from',
#  'holes',
#  '@',
#  'user',
#  '@',
#  'user',
#  'keep',
#  'calling',
#  'her',
#  'a',
#  'bitch',
#  'and',
#  'a',
#  'whore',
#  'dude',
#  'real',
#  'grown',
#  'up',
#  '.',
#  'Glad',
#  'your',
#  'having',
#  'another',
#  'nice',
#  'vacation',
#  '.',
#  'How',
#  "'s",
#  'the',
#  'illegal',
#  'border',
#  'crossings',
#  ',',
#  'illegal',
#  'oportunistic',
#  'migrant',
#  'entries',
#  ',',
#  'tax',
#  'payer',
#  'funded',
#  'hotel',
#  'rooms',
#  'for',
#  'same',
#  'without',
#  'a',
#  'strategic',
#  'plan',
#  'going',
#  '?',
#  '@',
#  'user',
#  '@',
#  'user',
#  '@',
#  'user',
#  '@',
#  'user',
#  '@',
#  'user',
#  '@',
#  'user',
#  '@',
#  'user',
#  'Unchecked',
#  'Population',
#  '&',
#  'amp',
#  ';',
#  'migration',
#  'to',
#  'cities',
#  'is',
#  'biggest',
#  'evil',
#  'for',
#  'dirty',
#  'India.Disincentive',
#  'large',
#  'families',
#  ',',
#  'such',
#  'as',
#  'withdrawl',
#  'of',
#  'sops',
#  'Illegal',
#  'Alien',
#  'Hit',
#  'Man',
#  ',',
#  'Dragged',
#  'Him',
#  'For',
#  'Blocks',
#  'In',
#  'Deadly',
#  'DUI',
#  'Crash',
#  '#',
#  'BuildTheWall',
#  '#',
#  'NoAmnesty',
#  '#',
#  'NoDACA',
#  '#',
#  'DeportThemAll',
#  '#',
#  'KeepAmericaSafe',
#  'An',
#  'Honest',
#  'Article',
#  'About',
#  'Illegal',
#  'Immigration',
#  'By',
#  'a',
#  'Lefty',
#  '?',
#  '?',
#  'Are',
#  'Pigs',
#  'Flying',
#  '?',
#  '-',
#  'A',
#  'miracle',
#  '...',
#  '@',
#  'user',
#  '@',
#  'user',
#  '@',
#  'user',
#  '@',
#  'user',
#  'please',
#  'spread',
#  'the',
#  'word',
#  '-',
#  '&',
#  'gt',
#  ';',
#  '&',
#  'gt',
#  ';',
#  'using',
#  'frequent',
#  'flyer',
#  'miles',
#  'to',
#  'reunite',
#  'immigrant',
#  'families',
#  '!',
#  'knuckle',
#  'up',
#  'cause',
#  'I',
#  "'ll",
#  'fight',
#  'for',
#  'mines',
#  'Yo',
#  'pussy',
#  'petty',
#  ',',
#  'U',
#  'wasting',
#  'time',
#  '..',
#  'U',
#  'seasonal',
#  ',',
#  'part',
#  'time',
#  'U',
#  'get',
#  'fucked',
#  'up',
#  'fuckin',
#  'w/',
#  'mine',
#  'U',
#  'lil',
#  'bitch',
#  'Yes',
#  ',',
#  'women',
#  'who',
#  'protest',
#  'are',
#  "'irrational",
#  "'",
#  "'hysterical",
#  "'",
#  "'bitters",
#  'spinsters',
#  "'",
#  '-',
#  'long',
#  'history',
#  'of',
#  'using',
#  'that',
#  'shit',
#  'to',
#  'dismi…',
#  '@',
#  'user',
#  'Not',
#  'all',
#  'men',
#  'are',
#  'animals',
#  '.',
#  'You',
#  'Libs',
#  'want',
#  'muslims',
#  'to',
#  'come',
#  'over',
#  'still',
#  '?',
#  'Better',
#  'pick',
#  'a',
#  'side',
#  '.',
#  'Federal',
#  'judge',
#  'to',
#  '#',
#  'Trump',
#  ':',
#  '``',
#  'imminent',
#  'danger',
#  '``',
#  'of',
#  '``',
#  'irreparable',
#  'injury',
#  'to',
#  '#',
#  'refugees',
#  ',',
#  'visa-holders',
#  '``',
#  ',',
#  'etc',
#  '.',
#  '@',
#  'user',
#  'This',
#  'bitch',
#  'whom',
#  'I',
#  'wo',
#  "n't",
#  'name',
#  'on',
#  'Facebook',
#  'is',
#  'such',
#  'a',
#  'shameless',
#  'woman',
#  'ruining',
#  'a',
#  'relationship',
#  '.',
#  '#',
#  'getalife',
#  '#',
#  'stopspreadinglies',
#  '#',
#  'hoe',
#  '@',
#  'user',
#  '@',
#  'user',
#  'Omg',
#  'he',
#  'gave',
#  'her',
#  'his',
#  'number',
#  'and',
#  'she',
#  'did',
#  "n't",
#  'say',
#  'no',
#  'what',
#  'a',
#  'cunt',
#  'The',
#  'girl',
#  'is',
#  'the',
#  'cunt',
#  'for',
#  'giving',
#  'it',
#  'to',
#  'some',
#  'random',
#  'fucktard',
#  'Why',
#  'we',
#  'need',
#  'to',
#  'protect',
#  'refugees',
#  'from',
#  'the',
#  '‘',
#  '˜big',
#  'ideas',
#  '’',
#  'designed',
#  'to',
#  'save',
#  'them',
#  '@',
#  'user',
#  '@',
#  'user',
#  '@',
#  'user',
#  '@',
#  'user',
#  '@',
#  'user',
#  '@',
#  'user',
#  '@',
#  'user',
#  'Kevin',
#  'Rosero',
#  'of',
#  'the',
#  'Latino',
#  'Immigrant',
#  'Experience',
#  'Oral',
#  'History',
#  'Project',
#  '#',
#  'NJHRIC',
#  '#',
#  'NewarkPublicLibrary',
#  'needs',
#  'help',
#  'identifying',
#  'Newark',
#  'Latino',
#  'immigrant',
#  'residents',
#  'to',
#  'interview',
#  'and',
#  'capture',
#  'their',
#  'stories',
#  'and',
#  'experiences',
#  '.',
#  'MORE',
#  'INFO',
#  ':',
#  '@',
#  'user',
#  'Are',
#  'you',
#  'pussy',
#  'grabbing',
#  'tonight',
#  '?',
#  '?',
#  'Some',
#  'people',
#  'really',
#  'dont',
#  'understand',
#  'why',
#  'I',
#  'get',
#  'so',
#  'upset',
#  'at',
#  'injustices',
#  'happening',
#  'in',
#  'this',
#  'country',
#  '.',
#  'Trust',
#  'me',
#  ',',
#  'it',
#  "'s",
#  'not',
#  'that',
#  'I',
#  'like',
#  'getting',
#  'my',
#  'panties',
#  'in',
#  'a',
#  'wad',
#  'over',
#  'dumb',
#  'things',
#  '.',
#  'It',
#  "'s",
#  'the',
#  'fact',
#  'that',
#  'people',
#  'like',
#  'me',
#  '(',
#  'minority',
#  ',',
#  'brown',
#  ',',
#  'immigrant',
#  ',',
#  'etc',
#  ')',
#  'r',
#  'suffering',
#  'and',
#  'it',
#  'affects',
#  'me',
#  'directly',
#  'I',
#  "'ve",
#  'been',
#  'called',
#  'a',
#  'son',
#  'of',
#  'a',
#  'whore',
#  'and',
#  'a',
#  'cunt',
#  'today',
#  'already',
#  '.',
#  'It',
#  "'s",
#  'not',
#  'even',
#  '1',
#  'yet',
#  'Pope',
#  'Francis',
#  ':',
#  'Immigrants',
#  'Provide',
#  '‘',
#  '˜Enrichment',
#  '’',
#  'to',
#  'Society',
#  ',',
#  'Not',
#  '‘',
#  '˜Threats',
#  '’',
#  'What',
#  'were',
#  'they',
#  'planning',
#  'to',
#  'do',
#  'with',
#  'the',
#  'immigrant',
#  'children',
#  'they',
#  'kidnapped',
#  '?',
#  'Slavery',
#  ',',
#  'sex',
#  'traffic',
#  ',',
#  'organ',
#  'harvesting',
#  '?',
#  'masturbate',
#  'intensive',
#  'for',
#  'that',
#  'whore',
#  'slut',
#  'The',
#  'Truth',
#  'about',
#  '#',
#  'Immigration',
#  '@',
#  'user',
#  '@',
#  'user',
#  'Must',
#  'Make',
#  'Illegal',
#  '#',
#  'Immigration',
#  'and',
#  'Over',
#  'Stays',
#  'a',
#  'Felon',
#  'Pass',
#  'Mandatory',
#  'E-Verify',
#  'for',
#  '#',
#  'Jobs',
#  'and',
#  'Welfare',
#  '#',
#  'Trump',
#  '#',
#  'MAGA',
#  '#',
#  'RedNationRising',
#  '@',
#  'user',
#  'immigration',
#  'on',
#  'mass',
#  'in',
#  'Europe',
#  'Kills',
#  'our',
#  'Culture',
#  'our',
#  'languages',
#  'and',
#  'over',
#  'stretches',
#  'our',
#  'own',
#  'resources',
#  'such',
#  'as',
#  'Hospitals',
#  ',',
#  'Schools',
#  ',',
#  'now',
#  'Italy',
#  ',',
#  'Greece',
#  ',',
#  'etc',
#  ',',
#  'Your',
#  'right',
#  'send',
#  'them',
#  'back',
#  'home',
#  ...]

# %%
train, vocab = padded_everygram_pipeline(2, all_tokens)
lm = Laplace(2)
lm.fit(train, vocab) # will result in 'ZeroDivisionError' if removed

# %%
from tqdm import tqdm
list_of_perplexity = []
list_of_unigrams = []
lower_tokens = []

for sentence in all_tokens: 
    for word in sentence: 
        lower_tokens.append(word.lower())

# creating ngram list from training tokens
for i in all_test_tokens:
    list_of_unigrams.append(list(bigrams(i)))

# removing empty strings from unigrams
for i in list_of_unigrams: 
    if len(i) == 0:
        list_of_unigrams.remove(i)

# creating a list of perplexities
for i in tqdm(list_of_unigrams): 
    list_of_perplexity.append(lm.perplexity(i))

results = pd.DataFrame(list(zip(list_of_unigrams, list_of_perplexity)),columns = ['bigram grouped sentences','perplexity'])
# Out:
# 100%|██████████| 1799/1799 [00:00<00:00, 7381.78it/s]

# %%
results['percentage'] = results['perplexity'] / len(my_dict)

# %%
results
# Out:
#                                bigram grouped sentences   perplexity  \
# 0     [(#, WorldCup), (WorldCup, Blog), (Blog, for),...  6974.947055
# 1     [(The, ðŸ‡ªðŸ‡ºEU), (ðŸ‡ªðŸ‡ºEU, discuss), (di...  9239.682076
# 2     [(@, user), (user, Thank), (Thank, you), (you,...  2640.115827
# 3     [(@, user), (user, @), (@, user), (user, Pay),...  6311.729127
# 4     [(Prom, is), (is, coming), (coming, up), (up, ...  3894.682634
# ...                                                 ...          ...
# 1794  [(Oooohhhh, bitch), (bitch, did), (did, n't), ...  5112.868825
# 1795  [(@, user), (user, Good), (Good, Luck), (Luck,...  3139.448968
# 1796  [(Bitch, you), (you, ca), (ca, n't), (n't, kee...  3397.078821
# 1797  [(@, user), (user, @), (@, user), (user, @), (...  1242.730552
# 1798  [(@, user), (user, hi), (hi, Best), (Best, l),...  8541.819081
#
#       percentage
# 0       0.337378
# 1       0.446923
# 2       0.127702
# 3       0.305298
# 4       0.188386
# ...          ...
# 1794    0.247309
# 1795    0.151855
# 1796    0.164316
# 1797    0.060111
# 1798    0.413167
#
# [1799 rows x 3 columns]
